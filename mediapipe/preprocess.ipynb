# %%
from library.mediapipe_mp_v2 import generate_keypoints_csv_parallel

# %%
root_videos_dir = "D:/la-u/ciclo 2025-1/Seminario/DATASET_UNILADO"
model_path       = "D:/la-u/ciclo 2025-1/Seminario/MODELO/Keypoints/mediaPipe/pose_landmarker_heavy.task"
output_csv_path  = "./csv/keypoints_final_unilado_640.csv"

generate_keypoints_csv_parallel(root_videos_dir, model_path, output_csv_path)
# Out:
# 🔍 640 videos encontrados. Usando 12 núcleos...
# ➡️ Escribiendo CSV en: d:\la-u\ciclo 2025-1\Seminario\Proyecto\mediapipe\csv\keypoints_final_unilado_640.csv (2213079 filas)
# 🎉 CSV generado con éxito.
