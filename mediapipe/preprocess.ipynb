# %%
from library.mediapipe_mp_v2 import generate_keypoints_csv_parallel

# %%
root_videos_dir = "D:/la-u/ciclo 2025-1/Seminario/DATASETPRUEBA"
model_path       = "D:/la-u/ciclo 2025-1/Seminario/MODELO/Keypoints/mediaPipe/pose_landmarker_lite.task"
output_csv_path  = "./csv/kp_dataset_video_mode.csv"

generate_keypoints_csv_parallel(root_videos_dir, model_path, output_csv_path)
# Out:
# 🔍 20 videos encontrados. Usando 12 núcleos...
# ➡️ Escribiendo CSV en: d:\la-u\ciclo 2025-1\Seminario\Proyecto\mediapipe\csv\kp_dataset_video_mode.csv (79332 filas)
# 🎉 CSV generado con éxito.
