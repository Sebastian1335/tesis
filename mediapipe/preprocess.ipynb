# %%
from library.mediapipe_v1 import generate_keypoints_csv

# %%
root_videos_dir = "D:/la-u/ciclo 2025-1/Seminario/DATASETPRUEBA"
model_path       = "D:/la-u/ciclo 2025-1/Seminario/MODELO/Keypoints/mediaPipe/pose_landmarker_lite.task"
output_csv_path  = "./csv/kp_dataset.csv"

generate_keypoints_csv(root_videos_dir, model_path, output_csv_path)
# Out:
# ✅ ALVARO (1).mp4: 121 frames procesados.
# ✅ ALVARO (10).mp4: 118 frames procesados.
# ✅ ALVARO (11).mp4: 108 frames procesados.
# ✅ ALVARO (12).mp4: 111 frames procesados.
# ✅ ALVARO (13).mp4: 108 frames procesados.
# ✅ ALVARO (14).mp4: 123 frames procesados.
# ✅ ALVARO (15).mp4: 109 frames procesados.
# ✅ ALVARO (16).mp4: 122 frames procesados.
# ✅ ALVARO (17).mp4: 129 frames procesados.
# ✅ ALVARO (18).mp4: 131 frames procesados.
# ✅ ALVARO (19).mp4: 128 frames procesados.
# ✅ ALVARO (2).mp4: 113 frames procesados.
# ✅ ALVARO (20).mp4: 130 frames procesados.
# ✅ ALVARO (3).mp4: 122 frames procesados.
# ✅ ALVARO (4).mp4: 120 frames procesados.
# ✅ ALVARO (5).mp4: 124 frames procesados.
# ✅ ALVARO (6).mp4: 119 frames procesados.
# ✅ ALVARO (7).mp4: 122 frames procesados.
# ✅ ALVARO (8).mp4: 119 frames procesados.
# ✅ ALVARO (9).mp4: 127 frames procesados.
# ✅ ARIANA_Z (1).mp4: 118 frames procesados.
# ✅ ARIANA_Z (10).mp4: 102 frames procesados.
# ...
