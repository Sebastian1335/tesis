# %%
from library.mediapipe import generate_keypoints_csv

# %%
root_videos_dir = "D:/la-u/ciclo 2025-1/Seminario/DATASETPRUEBA"
model_path       = "D:/la-u/ciclo 2025-1/Seminario/MODELO/Keypoints/mediaPipe/pose_landmarker_lite.task"
output_csv_path  = "./csv/kp_dataset.csv"

generate_keypoints_csv(root_videos_dir, model_path, output_csv_path)
# Out:
# ✅ ALVARO (1): 121 frames procesados.
# ✅ ALVARO (10): 118 frames procesados.
# ✅ ALVARO (11): 108 frames procesados.
# ✅ ALVARO (12): 111 frames procesados.
# ✅ ALVARO (13): 108 frames procesados.
# ✅ ALVARO (14): 123 frames procesados.
# ✅ ALVARO (15): 109 frames procesados.
# ✅ ALVARO (16): 122 frames procesados.
# ✅ ALVARO (17): 129 frames procesados.
# ✅ ALVARO (18): 131 frames procesados.
# ✅ ALVARO (19): 128 frames procesados.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 5
#       2 model_path       = "D:/la-u/ciclo 2025-1/Seminario/MODELO/Keypoints/mediaPipe/pose_landmarker_lite.task"
#       3 output_csv_path  = "./csv/kp_dataset.csv"
# ----> 5 generate_keypoints_csv(root_videos_dir, model_path, output_csv_path)
#
# File d:\la-u\ciclo 2025-1\Seminario\Proyecto\mediapipe\library\mediapipe.py:103, in generate_keypoints_csv(root_videos_dir, model_path, output_csv_path, video_extensions)
#     100                 continue
#     102             video_path = os.path.join(dirpath, fname)
# --> 103             rows = process_video(video_path, landmarker)
#     104             writer.writerows(rows)
#     106 print(f"🎉 CSV generado en: {output_csv_path}")
#
# File d:\la-u\ciclo 2025-1\Seminario\Proyecto\mediapipe\library\mediapipe.py:38, in process_video(video_path, landmarker)
#      36 # Detectar pose (modo IMAGE para no lidiar con timestamps)
#      37 try:
# ---> 38     results = landmarker.detect(mp_image)
#      39 except Exception as e:
#      40     print(f"❗ Error en frame {frame_count} de {video_filename}: {e}")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mediapipe\tasks\python\vision\pose_landmarker.py:352, in PoseLandmarker.detect(self, image, image_processing_options)
#     333 """Performs pose landmarks detection on the given image.
#     334
#     335 Only use this method when the PoseLandmarker is created with the image
#    (...)    347   RuntimeError: If pose landmarker detection failed to run.
#     348 """
#     349 normalized_rect = self.convert_to_normalized_rect(
#     350     image_processing_options, image, roi_allowed=False
#     351 )
# --> 352 output_packets = self._process_image_data({
#     353     _IMAGE_IN_STREAM_NAME: packet_creator.create_image(image),
#     354     _NORM_RECT_STREAM_NAME: packet_creator.create_proto(
#     355         normalized_rect.to_pb2()
#     356     ),
#     357 })
#     359 if output_packets[_NORM_LANDMARKS_STREAM_NAME].is_empty():
#     360   return PoseLandmarkerResult([], [])
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mediapipe\tasks\python\vision\core\base_vision_task_api.py:95, in BaseVisionTaskApi._process_image_data(self, inputs)
#      90 if self._running_mode != _RunningMode.IMAGE:
#      91   raise ValueError(
#      92       'Task is not initialized with the image mode. Current running mode:'
#      93       + self._running_mode.name
#      94   )
# ---> 95 return self._runner.process(inputs)
#
# KeyboardInterrupt:
